# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data 
data=pd.read_csv('/kaggle/input/titanic-dataset/Titanic-Dataset.csv')

# %%
# Display first 5 lines
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Display last 5 lines
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# Getting the shape of the dataset
print(f"The dataset contains {data.shape[0]} rows and {data.shape[1]} columns.\n")

# Displaying column names
print("Column Names:")
print(data.columns.tolist())
# Out:
# The dataset contains 891 rows and 12 columns.
#
# Column Names:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
# Summary statistics 
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df=pd.get_dummies(data['Sex'],drop_first=True)
df=df.astype('int64')
df
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
data=pd.concat([df,data],axis=1) 
data
# Out:
#      male  PassengerId  Survived  Pclass  \
# 0       1            1         0       3
# 1       0            2         1       1
# 2       0            3         1       3
# 3       0            4         1       1
# 4       1            5         0       3
# ..    ...          ...       ...     ...
# 886     1          887         0       2
# 887     0          888         1       1
# 888     0          889         0       3
# 889     1          890         1       1
# 890     1          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.drop('Sex',axis=1,inplace = True )

# %%
data=data.rename(columns={'male':'gender'}) # rename cloumn male by gender 
data
# Out:
#      gender  PassengerId  Survived  Pclass  \
# 0         1            1         0       3
# 1         0            2         1       1
# 2         0            3         1       3
# 3         0            4         1       1
# 4         1            5         0       3
# ..      ...          ...       ...     ...
# 886       1          887         0       2
# 887       0          888         1       1
# 888       0          889         0       3
# 889       1          890         1       1
# 890       1          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...

# %%
data.drop(['PassengerId','Name','Ticket'],axis =1 , inplace=True )

# %%
data.to_csv('data.csv', index=False)

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# Checking for missing values
d_null=data.isnull().sum()
d_null[d_null>0]
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#calculates the percentage of missing values
d_null=data.isnull().sum()
d_null[d_null>0]/data.shape[0]*100
# Out:
# Age         19.865320
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
sns.histplot(data.Age)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
data.Age.mean()
# Out:
# 29.69911764705882

# %%
data.Age.median()
# Out:
# 28.0

# %%
data.Age.mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
# fill missing values with median
data['Age'].fillna(data['Age'].median(), inplace=True)

# %%
data.Age.isna().sum()
# Out:
# 0

# %%
data.Age.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
#calculates the percentage of missing values in cabinn col
data.Cabin.isnull().sum()/data.shape[0]*100
# Out:
# 77.10437710437711

# %%
#drop cabin column
data.drop(columns='Cabin',inplace=True)

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
#tvalue (mode)
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)

# %%
data.isna().sum()
# Out:
# gender      0
# Survived    0
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.title('Check Missing data')
# Out:
# Text(0.5, 1.0, 'Check Missing data')

# %%
data
# Out:
#      gender  Survived  Pclass   Age  SibSp  Parch     Fare Embarked
# 0         1         0       3  22.0      1      0   7.2500        S
# 1         0         1       1  38.0      1      0  71.2833        C
# 2         0         1       3  26.0      0      0   7.9250        S
# 3         0         1       1  35.0      1      0  53.1000        S
# 4         1         0       3  35.0      0      0   8.0500        S
# ..      ...       ...     ...   ...    ...    ...      ...      ...
# 886       1         0       2  27.0      0      0  13.0000        S
# 887       0         1       1  19.0      0      0  30.0000        S
# 888       0         0       3  28.0      1      2  23.4500        S
# 889       1         1       1  26.0      0      0  30.0000        C
# 890       1         0       3  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.drop(columns=['Embarked'],inplace=True)

# %%
data0=pd.read_csv('data.csv')
slicing_0=data0.iloc[:7,:4]
slicing_0
# Out:
#    gender  Survived  Pclass   Age
# 0       1         0       3  22.0
# 1       0         1       1  38.0
# 2       0         1       3  26.0
# 3       0         1       1  35.0
# 4       1         0       3  35.0
# 5       1         0       3   NaN
# 6       1         0       1  54.0

# %%
slicing_0.Age.fillna(method='ffill')
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    35.0
# 6    54.0
# Name: Age, dtype: float64

# %%
slicing_0.Age.fillna(method='bfill')
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    54.0
# 6    54.0
# Name: Age, dtype: float64

# %%
data1=pd.read_csv('data.csv')
data1.drop(columns=['Embarked','Cabin'],inplace=True)
slicing_1=data1.iloc[:6,:4]
slicing_1
# Out:
#    gender  Survived  Pclass   Age
# 0       1         0       3  22.0
# 1       0         1       1  38.0
# 2       0         1       3  26.0
# 3       0         1       1  35.0
# 4       1         0       3  35.0
# 5       1         0       3   NaN

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
data_imputed = imputer.fit_transform(slicing_1) # Fit the imputer and transform the data

# %%
data_imputed
# Out:
# array([[ 1. ,  0. ,  3. , 22. ],
#        [ 0. ,  1. ,  1. , 38. ],
#        [ 0. ,  1. ,  3. , 26. ],
#        [ 0. ,  1. ,  1. , 35. ],
#        [ 1. ,  0. ,  3. , 35. ],
#        [ 1. ,  0. ,  3. , 31.2]])

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
simple_imputed_data1 = imputer.fit_transform(data1) # Fit the imputer and transform the data
data_SimpleImputer = pd.DataFrame(simple_imputed_data1, columns=data1.columns)
data_SimpleImputer
# Out:
#      gender  Survived  Pclass        Age  SibSp  Parch     Fare
# 0       1.0       0.0     3.0  22.000000    1.0    0.0   7.2500
# 1       0.0       1.0     1.0  38.000000    1.0    0.0  71.2833
# 2       0.0       1.0     3.0  26.000000    0.0    0.0   7.9250
# 3       0.0       1.0     1.0  35.000000    1.0    0.0  53.1000
# 4       1.0       0.0     3.0  35.000000    0.0    0.0   8.0500
# ..      ...       ...     ...        ...    ...    ...      ...
# 886     1.0       0.0     2.0  27.000000    0.0    0.0  13.0000
# 887     0.0       1.0     1.0  19.000000    0.0    0.0  30.0000
# 888     0.0       0.0     3.0  29.699118    1.0    2.0  23.4500
# 889     1.0       1.0     1.0  26.000000    0.0    0.0  30.0000
# 890     1.0       0.0     3.0  32.000000    0.0    0.0   7.7500
#
# [891 rows x 7 columns]

# %%
data2=data1.copy()
slicing_2=data2.iloc[:6,:4]
slicing_2
# Out:
#    gender  Survived  Pclass   Age
# 0       1         0       3  22.0
# 1       0         1       1  38.0
# 2       0         1       3  26.0
# 3       0         1       1  35.0
# 4       1         0       3  35.0
# 5       1         0       3   NaN

# %%
from sklearn.experimental import enable_iterative_imputer  
from sklearn.impute import IterativeImputer

#Create an Iterative Imputer instance
iterative_imputer = IterativeImputer()

#Impute missing values
imputed_data = iterative_imputer.fit_transform(slicing_2)

#Convert the result back to a DataFrame
imputed_data2 = pd.DataFrame(imputed_data, columns=slicing_2.columns)
imputed_data2
# Out:
#    gender  Survived  Pclass        Age
# 0     1.0       0.0     3.0  22.000000
# 1     0.0       1.0     1.0  38.000000
# 2     0.0       1.0     3.0  26.000000
# 3     0.0       1.0     1.0  35.000000
# 4     1.0       0.0     3.0  35.000000
# 5     1.0       0.0     3.0  29.028825

# %%
from sklearn.experimental import enable_iterative_imputer  
from sklearn.impute import IterativeImputer

#Create an Iterative Imputer instance
iterative_imputer = IterativeImputer()

#Impute missing values
imputed_data = iterative_imputer.fit_transform(data2)

#Convert the result back to a DataFrame
data_IterativeImputer = pd.DataFrame(imputed_data, columns=data2.columns)
data_IterativeImputer
# Out:
#      gender  Survived  Pclass        Age  SibSp  Parch     Fare
# 0       1.0       0.0     3.0  22.000000    1.0    0.0   7.2500
# 1       0.0       1.0     1.0  38.000000    1.0    0.0  71.2833
# 2       0.0       1.0     3.0  26.000000    0.0    0.0   7.9250
# 3       0.0       1.0     1.0  35.000000    1.0    0.0  53.1000
# 4       1.0       0.0     3.0  35.000000    0.0    0.0   8.0500
# ..      ...       ...     ...        ...    ...    ...      ...
# 886     1.0       0.0     2.0  27.000000    0.0    0.0  13.0000
# 887     0.0       1.0     1.0  19.000000    0.0    0.0  30.0000
# 888     0.0       0.0     3.0  23.274703    1.0    2.0  23.4500
# 889     1.0       1.0     1.0  26.000000    0.0    0.0  30.0000
# 890     1.0       0.0     3.0  32.000000    0.0    0.0   7.7500
#
# [891 rows x 7 columns]

# %%
data3=data1.copy()
slicing=data3.iloc[:6,:4]
slicing
# Out:
#    gender  Survived  Pclass   Age
# 0       1         0       3  22.0
# 1       0         1       1  38.0
# 2       0         1       3  26.0
# 3       0         1       1  35.0
# 4       1         0       3  35.0
# 5       1         0       3   NaN

# %%
from sklearn.impute import KNNImputer
knn_imputer = KNNImputer(n_neighbors=2)

#Impute missing values
imputed_data = knn_imputer.fit_transform(slicing)

#Convert the result back to a DataFrame
Knn_imputed_data3 = pd.DataFrame(imputed_data, columns=slicing.columns)
Knn_imputed_data3
# Out:
#    gender  Survived  Pclass   Age
# 0     1.0       0.0     3.0  22.0
# 1     0.0       1.0     1.0  38.0
# 2     0.0       1.0     3.0  26.0
# 3     0.0       1.0     1.0  35.0
# 4     1.0       0.0     3.0  35.0
# 5     1.0       0.0     3.0  28.5

# %%
knn_imputer = KNNImputer(n_neighbors=2)

#Impute missing values
imputed_data = knn_imputer.fit_transform(data3)

#Convert the result back to a DataFrame
data_KNNImputer = pd.DataFrame(imputed_data, columns=data3.columns)
data_KNNImputer
# Out:
#      gender  Survived  Pclass   Age  SibSp  Parch     Fare
# 0       1.0       0.0     3.0  22.0    1.0    0.0   7.2500
# 1       0.0       1.0     1.0  38.0    1.0    0.0  71.2833
# 2       0.0       1.0     3.0  26.0    0.0    0.0   7.9250
# 3       0.0       1.0     1.0  35.0    1.0    0.0  53.1000
# 4       1.0       0.0     3.0  35.0    0.0    0.0   8.0500
# ..      ...       ...     ...   ...    ...    ...      ...
# 886     1.0       0.0     2.0  27.0    0.0    0.0  13.0000
# 887     0.0       1.0     1.0  19.0    0.0    0.0  30.0000
# 888     0.0       0.0     3.0  20.0    1.0    2.0  23.4500
# 889     1.0       1.0     1.0  26.0    0.0    0.0  30.0000
# 890     1.0       0.0     3.0  32.0    0.0    0.0   7.7500
#
# [891 rows x 7 columns]

# %%
data4=data1.copy()
slicing_4=data4.iloc[:7,:4]
slicing_4
# Out:
#    gender  Survived  Pclass   Age
# 0       1         0       3  22.0
# 1       0         1       1  38.0
# 2       0         1       3  26.0
# 3       0         1       1  35.0
# 4       1         0       3  35.0
# 5       1         0       3   NaN
# 6       1         0       1  54.0

# %%
slicing_4.Age.interpolate(method='linear')
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    44.5
# 6    54.0
# Name: Age, dtype: float64

# %%
data_interpolate=data4.interpolate(method='linear')
data_interpolate
# Out:
#      gender  Survived  Pclass   Age  SibSp  Parch     Fare
# 0         1         0       3  22.0      1      0   7.2500
# 1         0         1       1  38.0      1      0  71.2833
# 2         0         1       3  26.0      0      0   7.9250
# 3         0         1       1  35.0      1      0  53.1000
# 4         1         0       3  35.0      0      0   8.0500
# ..      ...       ...     ...   ...    ...    ...      ...
# 886       1         0       2  27.0      0      0  13.0000
# 887       0         1       1  19.0      0      0  30.0000
# 888       0         0       3  22.5      1      2  23.4500
# 889       1         1       1  26.0      0      0  30.0000
# 890       1         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
def split_data(data, target_column):
    x = data.drop(target_column, axis=1)
    y = data[target_column]
    print(x.shape, y.shape, end='\n')
    return x, y  

# Call the function and store the returned values
x_data, y_data = split_data(data, 'Survived')

print(x_data.head())
print(y_data.head())
# Out:
# (891, 6) (891,)
#    gender  Pclass   Age  SibSp  Parch     Fare
# 0       1       3  22.0      1      0   7.2500
# 1       0       1  38.0      1      0  71.2833
# 2       0       3  26.0      0      0   7.9250
# 3       0       1  35.0      1      0  53.1000
# 4       1       3  35.0      0      0   8.0500
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
x_data_simple, y_data_simple = split_data(data_SimpleImputer, 'Survived')
# Out:
# (891, 6) (891,)

# %%
x_data_iterative, y_data_iterative = split_data(data_IterativeImputer, 'Survived')
# Out:
# (891, 6) (891,)

# %%
x_data_knn, y_data_knn = split_data(data_KNNImputer, 'Survived')
# Out:
# (891, 6) (891,)

# %%
x_data_interpolate, y_data_interpolate = split_data(data_interpolate, 'Survived')
# Out:
# (891, 6) (891,)

# %%
from sklearn.model_selection import train_test_split

# Function to split data into train and test sets
def splitting_train_test(x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42, shuffle=True)
    print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)  # Print shapes
    return x_train, x_test, y_train, y_test  # Return the values

x_train, x_test, y_train, y_test = splitting_train_test(x_data, y_data)
# Out:
# (712, 6) (179, 6) (712,) (179,)

# %%
x_train_simple, x_test_simple, y_train_simple, y_test_simple = splitting_train_test(x_data_simple, y_data_simple)
# Out:
# (712, 6) (179, 6) (712,) (179,)

# %%
x_train_iterative , x_test_iterative , y_train_iterative , y_test_iterative = splitting_train_test(x_data_iterative, y_data_iterative)
# Out:
# (712, 6) (179, 6) (712,) (179,)

# %%
x_train_knn ,x_test_knn, y_train_knn , y_test_knn = splitting_train_test(x_data_knn, y_data_knn)
# Out:
# (712, 6) (179, 6) (712,) (179,)

# %%
x_train_interpolate, x_test_interpolate, y_train_interpolate, y_test_interpolate = splitting_train_test(x_data_interpolate, y_data_interpolate)
# Out:
# (712, 6) (179, 6) (712,) (179,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
log_reg=LogisticRegression()

# %%
def all(model,x_train,x_test,y_train,y_test):
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    accuracy_test=accuracy_score(y_pred,y_test)*100
    accuracy_train=model.score(x_train,y_train)*100
    print('accuracy after train model :',accuracy_train)
    print('accuracy after test  model :',accuracy_test)

# %%
all(log_reg,x_train, x_test, y_train, y_test)
# Out:
# accuracy after train model : 80.19662921348315
# accuracy after test  model : 81.00558659217877

# %%
all(log_reg,x_train_simple, x_test_simple, y_train_simple, y_test_simple)
# Out:
# accuracy after train model : 80.0561797752809
# accuracy after test  model : 81.00558659217877

# %%
all(log_reg,x_train_iterative, x_test_iterative, y_train_iterative, y_test_iterative)
# Out:
# accuracy after train model : 80.47752808988764
# accuracy after test  model : 83.24022346368714

# %%
all(log_reg,x_train_knn, x_test_knn, y_train_knn, y_test_knn)
# Out:
# accuracy after train model : 79.63483146067416
# accuracy after test  model : 82.68156424581005

# %%
all(log_reg,x_train_interpolate, x_test_interpolate, y_train_interpolate, y_test_interpolate)
# Out:
# accuracy after train model : 79.49438202247191
# accuracy after test  model : 78.2122905027933
